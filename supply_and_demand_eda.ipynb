# %%
import pandas as pd

df = pd.read_csv('supply_and_demand.csv')
df.head()
# Out:
#    total power generation  power supply  hydroelectricity  thermal power  \
# 0               13602.245     11770.284           293.392       7744.468
# 1               11997.789     10104.745           295.060       6356.051
# 2               14186.038     11817.609           311.387       7974.022
# 3               14167.784     11813.758           329.972       8500.499
# 4               15943.048     13407.175           345.180       9539.204
#
#     nuclear  Renewable energy  self use  total power requirement  year  month
# 0  3558.910           173.514  1831.961                13602.241  2000      1
# 1  3164.412           289.222  1893.044                11997.789  2000      2
# 2  3125.995           406.206  2368.429                14186.035  2000      3
# 3  2640.143           343.144  2354.026                14167.785  2000      4
# 4  3092.071           430.720  2535.873                15943.047  2000      5

# %%
df.columns
# Out:
# Index(['total power generation', 'power supply', 'hydroelectricity',
#        'thermal power', 'nuclear', 'Renewable energy', 'self use',
#        'total power requirement', 'year', 'month'],
#       dtype='object')

# %%
df['year'].value_counts().sort_index()
# Out:
# 2000    12
# 2001    12
# 2002    12
# 2003    12
# 2004    12
# 2005    12
# 2006    12
# 2007    12
# 2008    12
# 2009    12
# 2010    12
# 2011    12
# 2012    12
# 2013    12
# 2014    12
# 2015    12
# 2016    12
# 2017    12
# 2018    12
# 2019    12
# 2020    12
# 2021    12
# 2022     2
# Name: year, dtype: int64

# %%
year_group = df.groupby(['year'])
year_group.get_group(2000)[['total power requirement', 'total power generation']]
# Out:
#     total power requirement  total power generation
# 0                 13602.241               13602.245
# 1                 11997.789               11997.789
# 2                 14186.035               14186.038
# 3                 14167.785               14167.784
# 4                 15943.047               15943.048
# 5                 16924.073               16924.070
# 6                 18077.524               18077.524
# 7                 17553.876               17553.876
# 8                 16246.254               16246.257
# 9                 16680.966               16680.969
# 10                14844.524               14844.528
# 11                14616.673               14616.673

# %%
year_df = df.groupby(['year'])['total power requirement', 'total power generation'].agg('sum')
year_df
# Out:
# d:\anaconda\envs\ml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#       total power requirement  total power generation
# year
# 2000               184840.787              184840.801
# 2001               188530.440              188530.477
# 2002               198828.887              198828.904
# 2003               209072.386              209072.422
# 2004               218396.631              218396.670
# 2005               227512.249              227512.267
# 2006               235530.125              235530.142
# 2007               243116.584              243116.608
# 2008               238305.364              238305.390
# 2009               230037.158              230037.176
# 2010               247058.867              247058.872
# 2011               252167.013              252167.025
# ...

# %%
year_df[['total power requirement']].plot()

# %%
year_df[[ 'total power generation']].plot(color="y")
